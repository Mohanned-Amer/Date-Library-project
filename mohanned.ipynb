# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanned-Amer/Date-Library-project/blob/main/mohanned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to google colab")
# Out:
# Welcome to google colab

# %%
print("Welcome to google colab")
# Out:
# Welcome to google colab
